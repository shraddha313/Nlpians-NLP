# %%
import json
import random

# List of computer science-related keywords
cs_keywords = [
    "algorithm", "data structure", "programming", "computer", "software", 
    "network", "database", "machine learning", "AI", "artificial intelligence",
    "computing", "code", "coding", "neural network", "deep learning", "blockchain",
    "runtime", "compiler", "operating system", "API", "application", "hardware",
    "CPU", "GPU", "RAM", "disk", "cache", "cloud computing", "cybersecurity", "encryption"
    # ... add more keywords as needed
]

def is_cs_related(text):
    # Convert text to lowercase and check if any of the keywords are present
    return any(keyword in text.lower() for keyword in cs_keywords)


selected_data = []

# Open the JSON file for reading
with open("s2ag.valid.0", "r") as json_file:
    for line in json_file:
        try:
            data = json.loads(line)
            # Check if the data has 'text' and 'id' keys and if the text is CS-related
            if 'text' in data and 'id' in data and is_cs_related(data['text']):
                selected_data.append(data)
        except json.JSONDecodeError:
            print("Invalid JSON data:", line)

# Shuffle the selected data to ensure randomness
random.shuffle(selected_data)

# Split the data into train and test sets
train_data = selected_data[:3000]
test_data = selected_data[3000:4000]

# Now you have 'train_data' and 'test_data' containing computer science-related entries
# Each entry is a dictionary with 'id' and 'text' keys

# %%
# Assume train_data is a list of dictionaries with keys 'id' and 'text'

# Loop through and create a formatted string for each entry
output_string = ""
for entry in test_data:
    entry_string = "ID: " + str(entry["id"]) + "\n" + "Text: " + entry["text"] + "\n\n"
    output_string += entry_string

# Save to a txt file with utf-8 encoding
with open("shraddha.txt", "w", encoding="utf-8") as file:
    file.write(output_string)

# %%
# Read the txt file
with open("shraddha.txt", "r", encoding="utf-8") as file:
    lines = file.readlines()

# Modify the lines as needed
for i in range(len(lines)):
    line = lines[i].strip()  # Remove leading/trailing white spaces
    if line.startswith("Text:"):
        # Check if the line doesn't end with punctuation (you can extend this list if needed)
        if not (line.endswith('.') or line.endswith('!') or line.endswith('?')):
            lines[i] = line + '.\n'

# Save the modified content back to the txt file
with open("shraddha2.txt", "w", encoding="utf-8") as file:
    file.writelines(lines)

# %%
# Read the txt file
with open("shraddha2.txt", "r", encoding="utf-8") as file:
    lines = file.readlines()

# Initialize a list to store the formatted content
formatted_lines = []

# Initialize buffer for collecting text
text_buffer = []

# Loop through the lines and format them
for line in lines:
    line = line.strip()
    if line.startswith("ID:"):
        # If there's content in the buffer, append it as a single paragraph
        if text_buffer:
            formatted_lines.append(" ".join(text_buffer))
            text_buffer = []
        formatted_lines.append(line)
    else:
        # Collect lines in buffer to eventually combine them into a paragraph
        text_buffer.append(line.replace("Text:", "").strip())

# Add any remaining text in the buffer as a paragraph
if text_buffer:
    formatted_lines.append(" ".join(text_buffer))

# Save the formatted content back to a new txt file
with open("shraddha3.txt", "w", encoding="utf-8") as file:
    file.write("\n".join(formatted_lines))

# %%
# Read the txt file
with open("shraddha3.txt", "r", encoding="utf-8") as file:
    lines = file.readlines()

# Filter out lines that start with "ID:"
filtered_lines = [line for line in lines if not line.startswith("ID:")]

# Save the filtered content back to the txt file (or a new one if you prefer)
with open("shraddha4.txt", "w", encoding="utf-8") as file:
    file.writelines(filtered_lines)

# %%
! pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from spacy) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from spacy) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from spacy) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from spacy) (1.24.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from spacy) (2.4.1)
# Requirement already satisfied: jinja2 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from spacy) (65.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\20200\appdata\roaming\python\python311\site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.5.0)
# Requirement already satisfied: pydantic-core==2.10.1 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: colorama in c:\users\20200\appdata\roaming\python\python311\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\20200\appdata\local\programs\python\python311\lib\site-packages (from jinja2->spacy) (2.1.3)

# %%
import spacy
from spacy.lang.en import English

# Read the text from the file
with open("shraddha4.txt", "r", encoding="utf-8") as file:
    whole_text = file.read()

nlp = English()  # Create an English language object
sentencizer = nlp.add_pipe("sentencizer")  # Add the sentencizer component to the pipeline

# Break text into chunks of 500,000 characters each
chunk_size = 500000
text_chunks = [whole_text[i:i + chunk_size] for i in range(0, len(whole_text), chunk_size)]

all_sentences = []
for chunk in text_chunks:
    doc = nlp(chunk)  # Process the chunk
    # Extract sentences from the doc and extend the all_sentences list
    all_sentences.extend([sent.text for sent in doc.sents])

# Save the sentences to a new txt file
with open("shraddha5.txt", "w", encoding="utf-8") as file:
    for sentence in all_sentences:
        file.write(sentence + "\n\n")  # Each sentence on a new line with a blank line in between
# Out:
# c:\Users\20200\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\Users\20200\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
# c:\Users\20200\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\.libs\libopenblas64__v0.3.23-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
import re
from word2number import w2n

def remove_urls(text):
    url_pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    return url_pattern.sub('', text)

def remove_special_characters(text):
    # Remove bullets, apostrophes, hyphens, and enumerators without merging words
    text = re.sub(r'[\•\’\-\–]', ' ', text) # Replacing with space
    text = re.sub(r'\d+\.', '', text)  # Removing enumerators
    return text

def process_numericals(text):
    # If the line is just a number or a decimal, return an empty string
    if re.fullmatch(r'\d+(\.\d+)?', text.strip()):
        return ''
    # Convert other numbers in the sentence to text
    text = re.sub(r'\b\d+\b', lambda m: str(w2n.word_to_num(m.group())), text)
    return text



with open("shraddha5.txt", "r", encoding="utf-8") as file:
    lines = file.readlines()

processed_lines = []
for line in lines:
    line = remove_urls(line)
    line = remove_special_characters(line)
    line = process_numericals(line)
    processed_lines.append(line)



with open("shraddha6.txt", "w", encoding="utf-8") as file:
    file.writelines(processed_lines)

# %%
import nltk
from nltk.corpus import words as nltk_words

nltk.download('words')

def is_valid_word(word, word_list):
    # Convert to lowercase and check if the word exists in the word list
    return word.lower() in word_list

def process_file(filename):
    # Load English words
    english_words = set(nltk_words.words())

    # Open the file with utf-8 encoding
    with open(filename, 'r', encoding='utf-8') as f:
        lines = f.readlines()

    processed_sentences = []
    all_words = set()

    for line in lines:
        # Convert to lowercase
        line = line.strip().lower()

        # Split into words and remove the trailing period
        words = [w.rstrip('.') for w in line.split()]

        # Filter out invalid words
        valid_words = [word for word in words if is_valid_word(word, english_words)]

        if valid_words:  # Only add sentences that have at least one valid word
            processed_sentence = ' '.join(valid_words)
            processed_sentences.append(processed_sentence)
            all_words.update(valid_words)

    # Save to new file
    with open('shraddha7.txt', 'w', encoding='utf-8') as f:
        for sentence in processed_sentences:
            f.write(sentence + '\n')

    # Get ordered unique sentences and words
    unique_sentences = sorted(set(processed_sentences))
    unique_words = sorted(all_words)

    # Print the results
    print("Ordered Unique Sentences:")
    for sentence in unique_sentences:
        print(sentence)
    print("\nSet of Words:")
    for word in unique_words:
        print(word)
    print("\nLength of Unique Sentences:", len(unique_sentences))
    print("Length of Set of Words:", len(unique_words))

process_file('shraddha6.txt')
# Out:
# [nltk_data] Error loading words: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# Ordered Unique Sentences:
# a an industrial and a wireless module are included in each device
# a analysis of research on intangible cultural heritage tourism the perspective of china
# a antibody the in a broad range of species and is one of the most widely used in motor research
# a approach for lower truncated normal cumulative application to reliability of used
# a bidirectional recurrent neural network that user as a time series classification problem is trained and tested to achieve near optimal we consider and power allocation with causal knowledge of the system which is an infinite state decision problem
# a body force model for the fan is and for axisymmetric and
# a brief review of its architecture is and a reference architecture is the key involved
# a brief review of the different of fabrication of and different fabrication by is articulated in this paper
# a calibration method for the identification of the between the absolute and is
# a case from us judicial practice is l v
# a case study of a six concrete frame isolated building was a combination of non linear that are currently available in several structural analysis and able to correctly model over stroke displacement behaviour for non linear time history analyses
# a categorical approximate approach for time of arrival
# a chance constrained model is established the nonlinear of
# a chance constrained optimization combined with soft open and control under in distribution
# a channel segmentation mechanism is designed for channel information by one channel of the three channel feature image as the main operation it with the secondary operation channel after and then the feature map into the convolutional neural network to realize the extraction and classification of bearing fault
# a chimeric antigen receptor an antigen binding domain is a portion of the a segment the and a cytoplasmic domain a and a intracellular
# a chimeric antigen receptor specific for was expressed on the surface of independent of endogenous
# a circular genome that protein and
# a classical integration a motion constrained and the method were through data
# a classifier by combining and can finally be used to diagnose brain
# a classifier is employed to the in the
# a classifier to detect number of dos attack against device in environment
# a closed loop current controller is to validate the proper operation of the source inverter topology
# a cluster satisfying the given confidence level is formed by a heuristic method to improve calculation efficiency
# a code analysis was carried out to determine in which language it is easier to implement an application with identical
# a collaborative model is then built based on the two and the between them
# a combining a inductive and deductive knowledge was used to highlight in the use of social visual and campaign
# a comparative analysis of the performance of sic level serial interference and sic level of noma non orthogonal multiple in a system with two is
# a comparative evaluative case study was and telephone with three health where robust leadership development were in place
# a comparative research on the effectiveness of two mobile for vocabulary and
# a comparative study of multiple ensemble of landslide susceptibility assessment in the upper half of county of the three area
# a comparison of different renewable based energy management for commercial
# a comparison of the dynamics of the resulting of attractiveness and the market of the studied a correlation and adequacy of the for practical application
# a comparison of the resulting series of of the with the corresponding of that the biological are on average relatively less suggesting that they may have been for linearity by natural selection for the purpose of controllability
# a comparison of the two with the traditional annotation method on both the synthetic and real is given
# a comparison with deterministic is given
# a comprehensive assessment of in and remote soil moisture data assimilation in the model for improving agricultural forecasting across the
# a comprehensive evaluation of extracted of extraction and expression revealed that the best in e whereas is better for complex mammalian
# a comprehensive search was to identify up to march in and
# a comprehensive study on structural and optical of the metal dielectric interface of o was an extension of the material portfolio available for optical system design
# a computer game based
# a computer model of speed position control of the rehabilitation system is
# a conceptual framework of an industry approach is then the application of different and of and industry at different of the realization of a project
# a conclusion on the need to revise the normative documentation for the design of construction of communication to include a calculated level of
# a conservative application of knowledge from these both individually and collectively that aged are able to provide their own consent to participate in and no legal or ethical principle the provision of parental consent on their behalf
# a content of in the best for removal from aqueous the maximum amount of on the membrane studied was
# a convolutional neural network model was by such as and data augmentation to the paddy rice disease
# a corresponding for summarization is by multiple based on the on top of which control were considered to specify for the of and token and n gram overlap
# a covid radiography of classes covid normal and viral pneumonia is
# a critical debate on the political economy of digital memory
# a cross sectional study on evaluation of diagnostic of linear transducer in various
# a cross sectional study on the among from
# a cross sectional study was admitted to royal infirmary and hospital with the primary diagnosis of from to march
# a cross sectional study was done with two hundred and eighteen post graduate public and basic medical from to at medical university
# a daily and m coupled and gross primary production product across china during
# a data driven innovation model of big data digital learning and its empirical study
# a data driven strategy for the parameter selection is as to make the whole procedure fully
# a data source dependency analysis framework for large scale data science
# a data transfer strategy is to deal with the data requirement among by a traveling salesman
# a decision making capability optimization scheme of control combination and controller for bivariate fertilizer applicator by
# a decrease in the duration of the disease was shown when the drug with the control group
# a deep learning model of prescient that they emerge from the periphery
# a deep neural network is trained only and tested with both and measured
# a deep q learning and neural network framework for trajectory
# a deep q learning approach is in this study by experienced replay and contextual to address these
# a deep understanding of the behavior of the and fracture will encourage the rapid development of new and lead to the better operation and maintenance of during their designed
# a deep understanding of the fracture mechanics in active is to meet the rapidly growing demand for next generation with long term high excellent and long life cycle
# a degree in chemistry a master s degree in chemistry and a doctorate in chemistry all from the university of brazil
# a descriptive research approach been and a t statistic been
# a detailed comparison between the information theoretic and the that along with the stability and owing to its ability to make an appeal to the the latter is superior to the former
# a detailed comparison of the and other related combined is also
# a differentiable and modular control stack for autonomous
# a discussion of the and of these is provided as a guide to aid in the most appropriate approach for future
# a disordered cube inspired framework for sodium ion with cycle
# a distinctive feature of such a game is that it a weighted in which and quota are rather than real
# a distributed hierarchical control model of a based on a consensus algorithm is in order to validate the methodology
# a distributed optimization based architecture for management of energy
# a disturbance observer based dual position feedback controller is herein to improve the accuracy by compensating for the in real time only an internal sensor
# a dual population based for constrained many objective optimization
# a dynamic detection method for in a soybean population based on an network
# a family of to compare two model driven development a traditional development method
# a fast novel recursive algorithm for the inverse of a generalized matrix
# a few merge the web of science and to conduct a single piece of research
# a field example was used to verify the correctness of the forward analysis and the effectiveness of the method
# a field study was over three
# a final diagnosis for this disease is often associated with additional time due to its relatively low prevalence
# a financial support from the king university of petroleum
# a finite difference method and optimization algorithm is used to the formulation and simulate this type of subsea cable problem concerning on the tensional analysis
# a five robot arm with a position controller was to verify the controller
# a fold cross validation that our is able to accurately emulate the behavior of absolute error for wind speed
# a follow up was after around four to investigate the effects of the
# a font of
# a force assembly force model based on was to overcome the incapacity of microscopic vision to properly identify the condition of after contact
# a forecast model of the gross output is with the relative and of the construction industry in from to as a training while the are the
# a friendly jammer is employed in order to improve the secrecy sum rate
# a frog leaping algorithm with q learning for unrelated parallel machine with additional resource and learning effect
# a full mathematical model of the been provided
# a fully connected neural network based on the double layer is and the recognition accuracy of is after training on the
# a further categorical analysis of the biological revealed that the of cancer and disease could not only be sometimes higher than but are also relatively more suggesting that the of disease may leverage the heterogeneity of regulatory to their advantage
# a further ten are as national
# a fuzzy control system is used to select the based on the input residual energy and node density of neighbor
# a general theory of fuzzy was texture
# a generalized methodology for gain with three is in this brief
# a genetically fluorescent we discovered that extracellular locally and transiently in absence of stimuli in neuron glia cortical and the mouse brain
# a good correlation was found
# a good neckline a sense of and vitality and an appearance of and beauty
# a graph is a type of that graph structure for semantic with and to represent and store data
# a graphitic carbon molybdate composite was a simple coprecipitation method and for the selective detection of
# a great potential in the development of digital health
# a high avidity of a specific t cell clone that was from donor was isolated and
# a high growth was to be coupled with high nutrient removal
# a high level of awareness of elder in addition to a high sense of responsibility towards the was
# a high throughput screen the structure activity relationship of the lasso peptide
# a hybrid implementation effectiveness study of implementation of plus long acting in eu health care key clinical and implementation by implementation arm
# a hybrid model approach was with neural network and and it the of a neural network with ready made training and improve the model to describe the asymmetric hysteresis
# a inverter prototype is built in the laboratory and the experimental are provided to verify the
# a is employed in this work to extract high level and deep from the
# a judicial trial is not for such heinous
# a laboratory study determined the contact of to honey bee
# a large amount of data is to train such
# a large number of banana
# a large part of the land out of is severely affected by salinity stress
# a large section of the population a source of income from the agriculture but their share in the is low
# a less restrictive approximation that is nearly exact for our system an equation of motion of form
# a light and free radical absorbing is produced in melanocyte that are found in but also in hair the inner brain and other
# a lightweight and secure three factor authentication protocol with adaptive privacy property for wireless sensor
# a lightweight attention collaborative fusion module was to efficiently fuse low level and high level to solve the problem that small infrared are easy to annihilate in the deep layer of the network
# a lightweight energy efficient packet size forwarding engine algorithm is the discrete event simulation methodological approach in for complexity evaluation
# a literature review of in and future prospective
# a literature review was in the web of scholar and to collect clinical and user satisfaction data on ar and compare those with ras
# a livable house is as the feasibility of a residential house which can be measured from namely the physical quality of the house and the quality of house
# a liver reconstruction algorithm is to obtain the approximate initial region of the which the requirement of prior knowledge and can reconstruct the liver region closer to the liver boundary
# a lot of can take place in such a landscape within the such as total or partial debris removal and reconstruction
# a m grid was selected as the evaluation unit
# a m khalifa introduction of the patient s face significantly enhanced assessment for accurate diagnosis and virtual treatment
# a machine for radiation treatment of artistic
# a made of and a high specific capacitance of
# a major change in medium and high where dominated the fermentation in and salt
# a major component of the new design is the three dimensional finite element method which a breakthrough in rigid pavement analysis
# a major physics breakthrough in when the and curie the piezoelectric which in formation of transducer
# a massive amount of electronic health is on the cloud due to the low cost and high usability
# a mathematical model was to quantitatively evaluate the impact of on the of two sample blood
# a matrix equation is built based on the rigid plate and rotational symmetry of the plate to determine the of freedom and bifurcation of structural motion
# a mechanical structure with high accuracy and strong stability was designed according to the shape of the linear insulator and the simulation of the artificial live working process
# a mechanistic transition from the monoclinic to the hexagonal behaviour is found for the structural evolution of and the improvement mechanism of is understood the combination of in and post synchrotron analyses
# a metastable lightweight high entropy alloy with the transformation induced plasticity
# a method is for efficiently surveillance at crossroads so that all transport network are taken into account
# a method of energy feature extraction based on wavelet packet decomposition was used to analyze the clustering center to obtain the frequency band with relatively high energy corresponding each damage mode further determined the actual damage pattern of these with classification
# a method to as swarm was used to segment
# a methodological approach is that the clarification of based on linguistic and ontological
# a methodologically original study of the dynamic response was on a unique dynamic model of the slewing superstructure that for continuous variation of the of the frequency of excitation by the resisting the excavation
# a microbial community growth model for dynamic phenotype
# a minor shift was in bacterial ecology from raw material towards low with
# a mixed integer nonlinear model is with respect to different and routing wave and wind tide and ship capacity
# a model cross modal retrieval is which triplet as the input and binary valued representation
# a model for smart i shop
# a model for the solution of the four from of the three is established
# a model free deep reinforcement learning the deep deterministic policy gradient is used to obtain the replacement and power allocation strategy
# a model of hippocampal replay driven by experience and environmental structure spatial learning
# a model of support and entrepreneurial with theory of behavior as case of youth
# a model with three is first established and some practical on the of the model are involved and
# a more comprehensive approach that on equitable the or economic which produce and contribute to and equitable organizational and specific that broaden participation and elevate from may be for meaningful and sustainable change
# a motor protein composed of the heavy chain and the light chain is fundamental to cellular morphogenesis and function
# a movement artefact free heart rate prediction system
# a multimodal for the prediction of exertion during resistance training
# a national defense context is provided to motivate the work and align with the intended purpose two resilience
# a necessary condition for the successful treatment of this disease is the identification of the root cause of its occurrence with its subsequent elimination
# a network user in a system is an entity that around a given optical
# a network was used to create a variable prediction tool to predict the year all cause mortality in with stage
# a neural style transferred glyph of of random initially distributed among the glyph gradually converging to glyph of a given character
# a new approach to etiotropic therapy in
# a new approach to optimize for insulator state identification based on algorithm
# a new concept of prevention of risky in and based on the of victor e s
# a new distributed time observer is added to estimate the desired velocity of each follower
# a new fly been recently discovered in
# a new fly species discovered from
# a new framework for and reconciliation of data
# a new hematocrit measurement method a chemiluminescence and its application in a chemiluminescence platform for myocardial detection with whole blood
# a new model of knowledge distance education
# a new sliding surface and a distributed protocol are to guarantee the achieve the bipartite consensus within a time
# a new solution presentation is
# a new the self adaptive neural network surrogate model differential evolution for antenna optimization is in this article
# a new type of paper made by highly efficient green light emissive zero dimensional organic manganese is rationally designed by virtue of the reversible photoluminescence off on switching
# a new variant of the eddy accumulation method for measuring atmospheric exchange is derived and a prototype sampler is
# a new veterinary graduate development been a framework of professional that are sufficiently flexible to create a program for each graduate depending on the role they enter
# a newly collected historical for the stock exchange is used to analyse the number and structure of listed equity
# a no code virtual serious game platform
# a non chemical and non completely ecological approach is used as an alternative removal treatment to control the these are the disinfection that were applied the rex machine
# a novel adaptive zero velocity detection algorithm based on general likelihood ratio test detector
# a novel algorithm based on voltage and current perturbation to track global peak under partial shading
# a novel approach is by combining barrier and bounded finite time command filter
# a novel based on the density based clustering algorithm density based spatial clustering of with noise is here
# a novel cache node selection algorithm is designed for optimal subscriber matching
# a novel design of pattern and frequency antenna is
# a novel form of like function is which in less stringent algebraic
# a novel metamorphic foot mechanism with toe based on spring loaded
# a novel method for bifurcation is based on the matrix of the constraint system and its expansion
# a novel method for digital generation from top view constrained dense matching
# a novel method for recursive systematic convolutional based on the cuckoo search algorithm
# a novel method for the non region by error correcting
# a novel s shaped frequency and pattern patch antenna for application
# a novel single nucleotide deletion in was which is to result in a reading
# a novel six of freedom mass spring damping based filter with time scale algorithm was to filter noise due to the multiple input noise and its frequency that is highly coupled with the basic sensor signal
# a novel technique distributed hybrid gene quadratic discriminant learning classifier system is in this paper
# a number of works on the design of various control for these electrical are
# a objective optimization based on evolutionary is used for the exhaust design
# a objective optimization is the tool to obtain the optimum for cutting velocity advance penetration depth and cutting angle of the tool
# a occurrence based model was used and the correlation with the similarity of brain activity was to that of affective
# a occurrence network for the research field of city logistics in the urban tourist area is with the use of the
# a one time memory two such that either bit can be but not both
# a optimal route is acquired for each prefecture pair by an navigation platform with its application time are given to down route to allocate traffic volume on that route to different then different are weighted with the origin destination traveler amount data from location based resulting in fine level prediction of the spatial temporal distribution of traffic volume on highway network
# a optimization model is and the constrained particle swarm optimization algorithm based on weight allocation is to obtain the optimal sequence
# a pairwise functional connectivity similarity measure method based on few shot learning for early detection
# a panel of metabolite were as candidate diagnostic
# a panel of metabolite were as candidate prognostic
# a part of this change could be due to residential household particularly with the increasing use of and battery powered with switch mode power
# a partial orientation of a graph g is a weak r guidance system if for any two vertices at distance at most r in g there a path p between them such that all but one edge in p towards this edge
# a partial solution of the is the model of a variable length link three
# a passive and paper based pump for variable flow
# a path strategy deep q learning on the network edge node is to enhance the driving performance of autonomous in of energy consumption
# a patient evidence literature review
# a peer to peer market is assumed to be present in the that the energy exchange among these that are through an electricity network and a district heating network
# a perovskite phase interfacial layer induced performance enhancement in based
# a phenomenological the present study is one of the few to explore the that contribute to the mental health of in the context of the pandemic crisis
# a plethora of
# a polysaccharide from
# a poor capacity for reuse
# a power distribution approach is in order to solve the issue of uneven power distribution of distributed generation in a ship
# a power information vulnerability detection system based on network traffic identification technology is designed
# a power information vulnerability detection system the problem of a low network survival rate
# a practical set of is in and a stationary solution to the process of in in a behavioral form is briefly
# a preclinical study
# a prerequisite for a parser for a language is a corpus with the desired linguistic known as a
# a privacy gait recognition scheme under homomorphic encryption
# a probabilistic neural network been to predict the malignancy of breast cancer based on a data the of which are used for the formulation and training of a model for a binary classification problem
# a promising idea in human cognitive is that the default mode network is responsible for the recruitment and of for and task specific cognitive
# a proper space vector modulation technique is to generate appropriate switching during all operating
# a prototype four grating is for verification of this proposal
# a public review is crucial for effectively such complementary professional
# a q learning algorithm is to dynamically decide search operator and search times
# a qualitative approach phenomenological inquiry was adopted
# a qualitative literature review
# a qualitative methodology was used for this which both primary and secondary to delineate the thesis of the study
# a quantum is the holy grail of quantum information the deployment of a broad range of quantum and on a global scale
# a quantum point contact model been to account for and the evolution of the conductive filament during
# a quasi two stage isolated bidirectional buck dab converter for wide input voltage range
# a rapid review was by systematically searching and literature to narratively compare permissive hypotension and fluid therapy
# a real life network a large number of least therefore this paper for set weighted in which the weighted form is taken into account
# a real world case study is to verify our conclusion
# a recent publication discovered one of the filamentary neutral hydrogen cattail from high resolution fast that might be a new galactic arm of the milky way
# a reconstruction method for rapid and acceptance of satellite batch production
# a reduction in the frequency of menstrual cycle related drug and quality of sleep and drinking water were the secondary of the post test and a month follow up
# a reference free r learner for treatment recommendation
# a relational user is then by item relation between all of a which not only fine grained but also the data sparsity problem
# a reliable algorithm for a class of singular nonlinear two point boundary value in physiology
# a reminder eight after the first
# a retrospective review of hospital was to identify who underwent related surgery and reconstruction from to
# a review of covid diagnostic in computer vision
# a review of life cycle assessment used to support the building design process
# a review of literature is which and of these relevance to design for building life cycle and data
# a review of mathematical covering s disease progression
# a review of prior art in converter synthesis that many converter are available for a given input and output specification
# a review of the influence of several such as the type and of photocatalyst of the the influence of and light intensity on photocatalytic of been provided
# a review on and performance of polymer
# a robust dual scheme based on melody feature is in this paper
# a scanning electron microscopy was used to characterize the distribution and the of the prepared
# a scattered wave spatial scanning method is to make full use of mode scattered for small scale abnormal geo near the well
# a second study was on irregularly worn carbide it was understood that location a significant role in the wear for the current the flank wear could be more effectively with the method than the wear on the rake side of the cutting tool
# a secondary objective was to explore the impact of dental to incorporate digital
# a selective sampling of in this study a item measurement scale and the theoretical model
# a self field soybean three dimensional color image acquisition vehicle was used to obtain and depth of soybean in the field
# a self questionnaire was distributed to the of prosthetic of the dental in
# a self voltage balanced hybrid three level inverter sic module with false trigger proof design
# a semantic network links the knowledge and the dependency of the in order to generate knowledge about future innovation
# a semi structured questionnaire was used to elicit information from the study after consent
# a semiotic study of the interplay between people and
# a sensor method was adopted to make the model adapt to the data of different so as to reduce the impact of experimental hardware on prediction accuracy
# a separate analysis that of quantitative genetic variation are more conducive to with sex in total expression than those without
# a separate chapter is devoted to mathematical of signal interaction with the propagation medium
# a sequence analysis of the selected for inclusion in this vaccine vaccine both hemagglutinin and that no occur in the antigenic of either hemagglutinin or that cell adaptation does not occur during production of this cell based vaccine
# a sequence optimization method for compressed sampling based on converter
# a serious exposure bias in training them from better
# a set of been formed in the field of responsible behavior of in the in the of the regional and other international
# a set of standard laboratory made it possible to define the content of crude while the fatty acid composition of seed was studied by gas chromatography in of methyl of fatty
# a shipboard power system optimal control problem with three control and the input is where three include the fast ess the bus voltage and the proportional load current
# a sic power module with low parasitic is applied as and the link capacitor can be self balanced through periodic with a small capacitor
# a signal is with electrical and phase noise characterization of and respectively
# a significant effort been made to develop advanced and with the aim of increasing performance and nominal with cycling
# a significant improvement in outcome in selected as suitable for conservative management been seen
# a significant increase in energy during the movement of the link been in comparison with the model of an ideal in which the control moment is which is a problem
# a significant increase in of fraud and various related in the last three
# a significant negative correlation of the zinc level in the with the age of men was revealed
# a significant number of valency based molecular have been which connect various physicochemical of chemical such as elastic and numerous
# a significant reduction to the cultivated of barley and soft wheat could lead to a potentially viable production plan
# a similar situation found in the classification system for smart by the international road congress association
# a simple method for the preparation of with high antioxidant activity and wide application range
# a simulation was to verify computational and design yielding the desired result which is to step up an input voltage of v to v in boost mode at a duty cycle of and step down an input voltage of v to v at the output during the buck mode at a duty cycle of
# a single center retrospective cohort study was
# a size of was after the application of and sample size determination formula
# a smaller heating power are more economical due to the dominant role of the monthly price related to the peak energy demand of the system
# a smart bus lane system based on object detection
# a source converter for hybrid energy storage
# a soybean pod quantity compensation model was established by the influence of the number of individual in the soybean population on the detection precision to statistically correct the pod quantity
# a stage attention mechanism is combining the convolutional neural network and the gated recurrent unit to construct the sa hybrid model
# a standard scale is the borg which from to highest exertion ever
# a statistical tagger conditional random field been for the of the test data
# a statistically significant association between and was for over h in admitted to an intensive care unit confidence interval to p and for low in non admitted to p
# a statistically significant difference was found in maxillary incisal display and lip form between male and female p and p but no statistically significant difference was found in mandibular incisor display between male and female p
# a strong correlation between lip form and incisal display in elderly population
# a study on the morphology and transfer of formed with high viscosity silver paste and small gap was in this paper
# a study text based and face to face to understand early school dropout
# a study was after which it was that the effect of did not depend on the degree of renal and was under the influence of loop
# a study was carried out on the effect of the substrate on the accumulation of by vegetable
# a substantial portion considered the lack of privacy and inadequate communication with the community as key
# a suitable gel ink form of this material for gel printing was together with a certain solvent
# a support vector machine model was therefore established for the identification of the normal and defective of the
# a survey of sign language recognition
# a survey on identification of artificial intelligence
# a survey research design was for this work with a population of all the staff of selected deposit money in state which was put at staff
# a synchronization technique for single phase grid
# a syndromic surveillance we of a rare disease of public health importance
# a system for the temperature of been made with lora data communication
# a system with memory semantic fabric for scalable graph
# a systematic electronic search was the and library
# a systematic literature review
# a systematic review of in undergoing continuous renal replacement does one size fit
# a systematic review of of accident prevention training
# a systematic review of of based bystander intervention related
# a systematic search of the literature in and was by two independent all case and case series concerning from until
# a technology acceptance model questionnaire was applied to determine the perception of utility and ease of use of the methodology
# a test device based on a and a method for measuring colorimetric in an additive system for and declared of dairy origin are
# a theory based analytic model is employed to mimic the of in the transportation system under the emergency preparedness state and a probability choice model is to the emergency preparedness of the system
# a thread control algorithm with update based on event triggered mechanism
# a three dimensional kinematic motion capture of and three other weight in a total of in this research
# a topological index as a graph parameter was mathematically from the graph s topological structure
# a total number of indexed were and a final selection of directly the issue was
# a total of from new and were included
# a total of male female were included in the model
# a total of of as well as ulcerative coli related were
# a total of of descent were at and were available for the present study
# a total of of which about considered the first place to visit if they have medication
# a total of people the survey mean
# a total of seven leadership and from three
# a total of the who were mostly or of
# a total of were among enrolled
# a total of were and of were included in the systematic review and in the meta analysis
# a total of were collected from the initial search and were ultimately included in the systematic review and meta analysis
# a total of were for each upper and lower limb movement in two different position concerning the
# a total of were included for a total of
# a total of were included in current literature review
# a total of were new from fresh based on a fragment of the cytochrome c oxidase subunit i gene
# a total of were of which eight were eligible for inclusion
# a total of were of which were original research and the were review
# a total of with had of which had a median of and underwent nephrectomy
# a total of with mean and white were had and of had positive
# a total of with pneumonia age were finally included
# a total of with relapsing and progressive secondary
# a transmission electron microscopy was used to investigate the shell
# a trend towards a shorter in with t cannot be and should be by further with a higher number of
# a tutorial on analysis of count data
# a two of car and abbreviation of provincial
# a two pronged strategy to alleviate tumor and potentiate photodynamic therapy by mild hyperthermia
# a two year study determined the decay rate of in blueberry after application
# a type of graphite intercalation was prepared in the presence of concentrated sulfuric acid in the presence of a potassium periodate oxidizer
# a unified model of suspension concentration distribution in sediment mixed turbulent generalized fractional advection diffusion equation
# a unique application methodology for the use of phosphorus inactivation and its effect on phosphorus speciation in with
# a user friendly application was for the optimum blade geometry special calculation
# a variety of are available to address these appliance to display the power factor of their or device
# a variety of biological and an impact on the metabolic process in the human body
# a very high percentage of the elderly in shelter were found to have experienced especially which in an array of mental health such as and sleep
# a video description model with attention mechanism
# a visualization platform based on and electronic navigational is designed to analyze the knowledge of ship motion
# a w prototype concerning to this converter is built and the proposal
# a was carried out in a real house in the city of over a one year where four were used to collect energy consumption smart as well as the main energy load of the house through a data logger acting as a smart meter
# a weigh in motion system continuously and automatically an object s weight during transmission
# about a third of diabetic have diabetic of any stage and have proliferative diabetic
# above of age had more maxillary incisal display as to but almost same mandibular incisal display
# absence of substance is also essential for its development
# abstinence is an integral part of availability of effective non pharmacological for treatment of addiction is an essential first step
# abstract
# abstract a well neck is an artistic imperative to an attractive and appealing appearance
# abstract and fitness often suffer muscle during their training
# abstract background and is the most used federally illicit substance
# abstract bacteriophage is a isolated in from soil on the coastal university campus in south the host
# abstract cervical syndrome is one of the most common painful of modern times
# abstract digital literacy is important in many of such as remote public on the goods and participation in political and cultural entertainment and leisure
# abstract early and late gene of have been known to rely on host and a virus separately
# abstract gonadal dysgenesis with a case report
# abstract introduction one of the main of modern basketball physiology is high performance and improving its physical condition
# abstract investigating primary cancer tumor and liver metastasis through whole of synchronous
# abstract machine learning are being used frequently in a variety of
# abstract microbial in coastal are diverse and dynamic and play important in ecosystem and
# abstract objective this study to evaluate the accuracy in of trueness and precision of eight intraoral and the effect of different finishing line on the accuracy
# abstract of fibrotic to control progression
# abstract real life of deep learning are often limited by the lack of expert data to effectively train
# abstract recent cross linguistic research that use a prosodic mitigation strategy when higher status by talking more reducing the intensity and lowering the overall fundamental frequency
# abstract spatial proximity between t and tumor with invasive recurrence in
# abstract t cell receptor like chimeric antigen receptor to recognize derived from driver
# abstract the blood culture identification panel is a fully based assay for and bacterial resistance in positive blood in about h in this we the performance of the panel for pathogen detection in positive
# abstract the distribution of a normally distributed hardware is to a lower truncated normal distribution after it been in service for a certain period
# abstract the monetary crisis that hit people to look for other economic namely the economy
# abstract the present study the relative effectiveness of digital used on when with traditional paper based in teaching vocabulary from recently corpus based general and academic word
# abstract the present work the scholarly community to a information about the and of the first world war in the which data extracted from the to to these social as its main
# abstract the who endorsed the use of stool for diagnosis of tuberculosis in and targeted next generation of stool been shown to support diagnosis and provide information about drug susceptibility
# abstract this article the effect of on the post fatigue fracture resistance of adhesively simplified in lithium disilicate glass ceramic
# abstract this paper the ongoing development of forensic anthropology in
# abstract with the gradual improvement of the theoretical system of sports biomechanics and the high of the scientific research of is no longer restricted to a sports biomechanics is a combination of the complex of movement and body in the a discipline that the of mechanics and biology for research
# abstractive unlike extractive does not only copy essential from the original text but to get close to human summary
# abundant of frontotemporal lobar degeneration with and related tau in a family with a mutation
# according to art
# according to field the best and most appropriate output for fuzzy integration are the use of a compromise operator in the range of to
# according to such a this review at the current and at the upcoming in upper limb prosthetic
# according to systematic comparison analyses among three forecast the neural and grey the that the forecast model the higher solution accuracy and generalization ability
# according to term occurrence this paper several within the field
# according to the are the key in the structural support of semiconductor based photocatalytic and the enhancement of which that have high reuse potential in sustainable photocatalysis
# according to the concept of the state actually the right to totally limit the political of former of corruption not to go forward again or to abolish them in order to guarantee the integrity of the government from corrupt in the future and also to make the law a function of deterrent effect and the last remedy in but in fact the state does not implement the state to give access to ex corruption to advance to become for regional on the legal basis of this decision
# according to the conceptual some plastics into the structure of an explosive in appropriate can improve the energy of a high energy material
# according to the covid significantly the mobile adoption rate and the number of buy sell in capital market
# according to the experimental the tracker better than other cutting edge when faced with various
# according to the final solution of the optimization the generator matrix of recursive systematic convolutional code is
# according to the hardness the sub zero treatment is effective in hardening where the hardness value as the sub zero treatment time ranging from to
# according to the importance the important affecting the occurrence of are terrain surface texture distance to distance to and land use
# according to the of the a large system decomposition aggregation dynamic method is to transform n dimensional dynamic problem into n one dimensional dynamic problem for solution
# according to the of this it was that the shape index value might be related to egg weight
# according to the study the top of the concrete slab layer had an increase in stress of approximately when its thickness from to whereas the top of the subgrade layer had a decrease of about in stress
# according to the taxonomic of the five strain could be divided into four
# according to the the thermochemical and resultant powder phases good coherency
# according to the usage of social their confidence in their capacity to succeed and their desire to do so
# according to the variation of the it was that better compatibility with the workability of the solution and improving the final of the relative to
# according to this are social that regulate the behavior of in a certain area of international
# according to this the process statistical model to be appropriate and the goal of optimization
# according to who definition of s a process between two or more learn about and with one another to permit effective association and enhance health outcome
# according to world health organization diabetes million people in the world most of them from low and middle income and social
# accumulative evidence that many such as genus were associated with the presence of alkaloid
# accuracy estimation of the calculating algorithm the satellite s orbit of earth remote
# accuracy of cone beam tomography and digital radiography versus clearing technique in detection of confluent in mandibular
# accuracy of digital face from two different a comparative clinical study
# accurate and diagnosis of the pancreatic tumor is a demanding task due to several such as diagnosis and absence of early warning
# accurate estimation of the battery system state of charge is essential to the satellite mission design and fault management
# accurate high resolution actual and gross primary production information is essential for understanding the large scale water and carbon dynamics
# accurately the annual in and in the with a dual system
# acid based medicinal are promising for inclusion in combination antiepileptic therapy
# acid is a polymer with wide range of in food and medical
# acid is commonly derived from lactic acid which is made from sugar and starch via bacterial fermentation
# acid the frequency of epileptic and intellectual and mnestic in with epilepsy
# acid was at a dose of acid and were at a dose of
# acridine are a class of that are being extensively as potential anti cancer
# acridine as an anti a critical review
# acridine platinum have shown specificity on the which and a methyl moiety were also studied
# acridine thiourea gold and act against cell such as and
# acritical intelligent such as long and short term memory have been widely considered promising for engine performance especially for engine emission performance prediction and and transformer is also gradually applied to sequence prediction
# across all maximum gain in vol ranged between and at age to and was linearly correlated to the amount of during the first year after planting
# across all need to be that first account for an opportunity when measuring actual bystander behavior
# across the evolutionary history of fungus growing the of origin of most of correspond to the of origin of the fungus growing whose they parasitize
# actin filament are key in this activity and include the actin related protein that dendritic of branched as well as a large family of that typically generate unbranched and
# activation to forming high quality for unsupervised salient object detection
# active learning is a practical field of machine learning as data or which data to label can be a time consuming and inefficient task
# active learning is a sub field of machine learning which to ease this burden by the model to select which data would be most beneficial to so that the entirety of the does not need to be
# active learning the process of which data to but current are heavily model reliant
# active learning with combinatorial coverage
# active upper limb a review on current state and upcoming
# actual in the usability of as a high value product of through pyrolysis
# actual year survival was
# actual year survival was lost to follow
# acute kidney injury intravascular coagulation and surgical site bleeding were the commonly associated
# adaptable approximate multiplier design based on input distribution and polarity
# adaptive latent graph representation learning for image text matching
# adaptive time accumulation which the system s dynamic range and many to flux measurement and calculation
# adaptive time delay estimation and control of robot
# adaptive time delay fictitious signal generation
# additional controllable such as fuel are because of their reduced efficiency and nature
# adherence to all the except for renin system was significantly lower in the group with depression than in the group without
# ...
# retrieval
# retrieve
# retrospective
# retrospectively
# return
# reunification
# reuse
# rev
# reveal
# revealed
# revealing
# revenue
# reversal
# reverse
# reversibility
# reversible
# review
# revise
# revision
# revisit
# revolution
# reward
# rex
# rhetorical
# rhizosphere
# rho
# rhombohedral
# ribbon
# ribonuclease
# rice
# rich
# richness
# rid
# right
# rigid
# rigidity
# rigor
# rigorous
# rim
# ring
# rio
# riparian
# rise
# rising
# risk
# risky
# river
# riverside
# road
# rob
# robin
# robot
# robust
# robustly
# robustness
# roc
# rock
# rocket
# rod
# roi
# role
# roll
# rollback
# rolling
# romance
# romantic
# roof
# roofing
# room
# root
# rooted
# ropes
# rose
# rosemary
# rosette
# rotary
# rotating
# rotation
# rotational
# rotor
# rotten
# rouge
# rough
# roughly
# roughness
# round
# rounded
# route
# routine
# routinely
# routing
# row
# royal
# rubber
# rue
# rugged
# rule
# run
# runaway
# running
# rupture
# rural
# russia
# rutile
# s
# sa
# sac
# saccharomyces
# sacral
# sacrificial
# sad
# saddle
# safe
# safeguard
# safely
# safety
# sag
# sage
# sailing
# saint
# sake
# sal
# salesman
# salicylic
# salient
# saline
# salinity
# saliva
# salt
# sam
# same
# sample
# sampler
# sampling
# san
# sand
# sandy
# sanger
# sanitary
# sanitation
# sap
# sar
# sarcoma
# satellite
# satisfaction
# satisfactorily
# satisfactory
# satisfied
# satisfy
# satisfying
# saturated
# saturation
# save
# saved
# saving
# saw
# sawdust
# say
# scaffold
# scaffolding
# scalable
# scalar
# scale
# scaled
# scales
# scaling
# scalp
# scan
# scanner
# scanning
# scarce
# scarcely
# scarcity
# scatter
# scattered
# scattering
# scavenge
# scavenging
# scenario
# scene
# schedule
# schema
# scheme
# schizophrenia
# scholar
# scholarly
# scholarship
# school
# science
# scientific
# sclerosis
# scope
# score
# scored
# scoring
# scramble
# scratch
# screen
# screened
# screening
# screw
# screwing
# script
# scutellum
# se
# sea
# sealant
# search
# searching
# season
# seasonal
# second
# secondary
# secondly
# secrecy
# secretory
# section
# sectional
# sector
# sectoral
# secure
# security
# sediment
# sedimentation
# see
# seed
# seeded
# seedling
# seek
# seeker
# seeking
# seem
# seen
# seepage
# segment
# segmentation
# segmented
# seismic
# seize
# seizure
# seldom
# select
# selected
# selection
# selective
# selectively
# selectivity
# selenite
# selenium
# self
# selfish
# sell
# selling
# semantic
# semantically
# semester
# semi
# semiautomatic
# semiconducting
# semiconductor
# semiotic
# send
# sending
# senescence
# sense
# sensed
# sensibility
# sensible
# sensitive
# sensitivity
# sensitization
# sensor
# sensorimotor
# sensory
# sent
# sentence
# sentient
# sentinel
# separability
# separate
# separately
# separating
# separation
# sepic
# sepsis
# sept
# sequelae
# sequence
# sequential
# sequentiality
# sequentially
# sequester
# sequestration
# ser
# serial
# serially
# series
# serine
# serious
# seriously
# serum
# serve
# server
# service
# serving
# sesame
# session
# sessions
# set
# setback
# setting
# settlement
# settling
# setup
# seven
# seventeen
# seventeenth
# seventh
# seventy
# several
# severe
# severely
# severity
# sewer
# sewing
# sex
# sexual
# sexually
# shade
# shading
# shadow
# shaft
# shale
# shallow
# shampoo
# shape
# shaped
# shaping
# share
# sharer
# sharp
# she
# shear
# sheath
# shed
# shedding
# sheep
# sheer
# sheet
# shelf
# shell
# shelter
# shielding
# shift
# shifting
# ship
# shipboard
# shipping
# sho
# shock
# shoot
# shooting
# shop
# shopping
# shore
# short
# shortage
# shortcoming
# shortening
# shorter
# shot
# should
# shoulder
# show
# showcase
# showing
# shown
# shrinking
# shunt
# si
# sialic
# sic
# sicilian
# sick
# side
# sided
# sides
# sideways
# sieve
# sig
# sight
# sighted
# sigma
# sigmoid
# sign
# signal
# signature
# signer
# significance
# significant
# significantly
# signify
# signum
# silage
# silence
# silent
# silica
# silicate
# silico
# silicon
# silo
# silt
# silty
# silver
# similar
# similarity
# similarly
# simp
# simple
# simpler
# simplex
# simplicity
# simplification
# simplified
# simplify
# simplistic
# simply
# simulate
# simulation
# simulator
# simultaneous
# simultaneously
# sin
# since
# sine
# single
# singleness
# singlet
# singular
# singularity
# singularly
# sink
# sinusoidal
# sion
# sir
# sister
# site
# sitting
# situated
# situation
# situational
# six
# sixteen
# sixteenth
# sixth
# sixty
# size
# sized
# sizes
# skeletal
# skeleton
# sketch
# skewed
# skill
# skin
# skip
# slab
# slack
# slam
# slang
# slat
# slaughter
# sleep
# sleeping
# slender
# slewing
# slice
# slicing
# slide
# slider
# sliding
# slight
# slightly
# slime
# slip
# slippage
# slope
# slot
# slotted
# slow
# slowly
# sludge
# sluggishly
# small
# smaller
# smart
# smartness
# smell
# smile
# smith
# smoke
# smoking
# smoky
# smooth
# smoother
# smoothing
# smoothly
# smote
# smuggling
# snapshot
# snow
# snowball
# so
# soc
# social
# socialization
# socially
# societal
# society
# sociocultural
# socioeconomic
# sociologist
# socket
# sod
# sodium
# soft
# softening
# soil
# solar
# solder
# sole
# solely
# solicited
# solid
# solitary
# solo
# solubility
# solution
# solve
# solvent
# solver
# somatic
# some
# something
# sometimes
# somewhat
# somewhere
# sonic
# soon
# sophisticated
# sorghum
# sorption
# sort
# sorted
# sought
# sound
# source
# south
# southeast
# southern
# southwest
# southwestern
# sowing
# sown
# soybean
# space
# spaced
# spacer
# spacing
# spacious
# span
# spare
# spark
# sparrow
# sparse
# sparsity
# spatial
# spatially
# spatiotemporal
# speaking
# spear
# spearman
# special
# specialist
# specialize
# specialized
# specially
# speciation
# species
# specific
# specifically
# specification
# specificity
# specify
# specimen
# spectra
# spectral
# spectrometer
# spectrometry
# spectrophotometric
# spectroradiometer
# spectroscopic
# spectroscopy
# spectrum
# speculate
# speculation
# speculative
# sped
# speech
# speed
# spend
# spending
# spent
# sperm
# spermatozoa
# sphere
# spherical
# spice
# spike
# spiked
# spiking
# spill
# spin
# spinal
# spine
# spinning
# spinocerebellar
# spiral
# spirit
# spirochete
# spite
# splanchnic
# splash
# splenic
# splicing
# spline
# split
# splitting
# spoilage
# spoiled
# spoke
# spontaneous
# spontaneously
# sporadic
# sport
# sports
# spot
# spotted
# spotting
# spray
# spread
# spreading
# spring
# square
# squared
# squat
# squeezing
# st
# stability
# stabilization
# stabilize
# stable
# stably
# stack
# staff
# stage
# staged
# staining
# stainless
# stake
# stakeholder
# stance
# stand
# standard
# standardization
# standardized
# standing
# standpoint
# stannous
# staphylococcus
# staple
# star
# starch
# start
# starting
# state
# stated
# statehood
# statement
# static
# statically
# statics
# station
# stationary
# statistic
# statistical
# statistically
# statistics
# stator
# status
# stay
# stays
# steadily
# steady
# steam
# stearyl
# steel
# steep
# steeper
# steepness
# steer
# steering
# steganography
# stellar
# stem
# stenosis
# step
# stephane
# stepping
# stepwise
# stereo
# steroid
# stickers
# stiff
# stiffness
# stigma
# still
# stimulate
# stimulation
# stimulator
# stimuli
# stimulus
# sting
# stochastic
# stock
# stocks
# stoichiometric
# stoichiometry
# stolen
# stomach
# stomatal
# stone
# stoner
# stool
# stop
# stopping
# storage
# store
# storm
# story
# storytelling
# straggling
# straight
# straightforward
# strain
# strand
# strange
# strap
# strata
# strategic
# strategically
# strategy
# stratification
# stratified
# stratify
# stratigraphic
# stratum
# straw
# stray
# stream
# streaming
# street
# strength
# strengthen
# strengthening
# strenuous
# streptococcus
# stress
# stressful
# strict
# strictly
# striking
# string
# stringent
# strip
# stripped
# stroke
# stromal
# strong
# strongly
# structural
# structurally
# structure
# structured
# struggle
# stuck
# student
# studied
# studio
# study
# stuff
# stump
# stunning
# style
# stylistic
# styrene
# sub
# subclass
# subclinical
# subcortical
# subcutaneous
# subgrade
# subgroup
# subject
# subjected
# subjective
# submarine
# submental
# submerged
# submission
# submit
# suboptimal
# subproblem
# subsample
# subscriber
# subsea
# subsequent
# subsequently
# subset
# subside
# subsonic
# subspecialist
# substance
# substantial
# substantially
# substantiate
# substantiation
# substation
# substrate
# subsurface
# subsystem
# subthalamic
# subtle
# subtropical
# subtype
# subunit
# subway
# succeed
# success
# successful
# successfully
# succession
# successive
# such
# sudden
# suffer
# suffering
# sufficiency
# sufficient
# sufficiently
# sugar
# suggest
# suggesting
# suggestive
# suicide
# suing
# suitability
# suitable
# suitably
# suite
# sulcus
# sulfuric
# sulphur
# sultanate
# sultry
# sum
# summarization
# summarize
# summary
# summer
# sun
# sunlight
# superbly
# superfamily
# superficial
# superimposed
# superimposition
# superior
# superiority
# supernova
# superposition
# supersedure
# supersonic
# superstitious
# superstructure
# supervision
# supplemental
# supplementary
# supplementation
# supplier
# supply
# support
# supporting
# supportive
# suppress
# suppressed
# suppression
# suppressive
# supremacy
# supreme
# surely
# surface
# surge
# surgeon
# surgery
# surgical
# surprise
# surprising
# surprisingly
# surrogate
# surround
# surrounded
# surrounding
# surveillance
# survey
# survival
# survive
# susceptibility
# susceptible
# suspected
# suspenseful
# suspension
# suspicion
# suspicious
# sustain
# sustainable
# sustained
# sustaining
# sustainment
# swab
# swampy
# swapping
# swarm
# sweeping
# swelling
# swimming
# swing
# switch
# switched
# switching
# swollen
# syllable
# syllabus
# symbiosis
# symbiotic
# symbol
# symbolic
# symmetric
# symmetrical
# symmetry
# symptom
# symptomatic
# synapse
# synapses
# synaptic
# synchronization
# synchronized
# synchronous
# synchrony
# synchrotron
# syncope
# syndrome
# syndromic
# synergistic
# synergy
# synod
# synonymous
# synopsis
# synthesis
# synthesize
# synthetic
# system
# systematic
# systematically
# systematics
# systematization
# systemic
# systolic
# t
# ta
# table
# tables
# tablet
# tackle
# tackling
# tactic
# tactics
# tag
# tagged
# tagger
# tail
# tailed
# tailor
# tailoring
# take
# taken
# taking
# talent
# tales
# talking
# tam
# tamper
# tandem
# tangible
# tanh
# tank
# tap
# tape
# taper
# tar
# target
# targeted
# task
# tau
# taught
# tax
# taxation
# taxonomic
# taxonomy
# te
# tea
# teacher
# teaching
# team
# teamwork
# teaser
# technical
# technically
# technique
# technological
# technology
# tedious
# teeth
# telecommunication
# telegram
# telemetry
# telephone
# television
# teller
# telling
# temperature
# template
# temporal
# temporally
# temporary
# temporoparietal
# ten
# tend
# tendency
# tender
# tenet
# tensile
# tension
# tensional
# tent
# tenth
# terephthalate
# term
# terminal
# terminate
# termination
# ternary
# terrace
# terrain
# terrestrial
# territory
# terrorism
# terrorist
# tertiary
# test
# tested
# testing
# testis
# text
# textbook
# textile
# textual
# textural
# texture
# th
# than
# thank
# thanks
# that
# the
# theft
# their
# them
# thematic
# theme
# themselves
# then
# theological
# theology
# theorem
# theoretic
# theoretical
# theoretically
# theory
# therapeutic
# therapeutics
# therapy
# there
# thereby
# therefore
# therewithal
# thermal
# thermo
# thermochemical
# thermodynamic
# thermodynamics
# thermoelectric
# these
# theses
# thesis
# they
# thiamine
# thick
# thickener
# thickness
# thin
# thing
# think
# thinking
# thinner
# thiol
# thiourea
# third
# thirteen
# thirty
# this
# thoracic
# thorax
# thorough
# thoroughly
# those
# though
# thought
# thoughtful
# thousand
# thread
# threat
# threaten
# threatening
# three
# threonine
# threshold
# thrice
# thrombocytopenia
# thrombosis
# thrombus
# throttle
# through
# throughout
# throughput
# thrust
# thruster
# thus
# thyme
# thymic
# thymine
# thymoma
# thyroid
# ti
# tidal
# tide
# tier
# tiger
# tight
# tighten
# tile
# tilt
# time
# timeliness
# timely
# timer
# times
# timing
# tin
# tiny
# tip
# tipping
# tire
# tissue
# titania
# titanic
# titanium
# title
# to
# tobacco
# today
# toe
# together
# toilet
# token
# tolerability
# tolerance
# tolerant
# tolerate
# toll
# tomato
# tomography
# tone
# too
# took
# tool
# toolbox
# tooth
# top
# topic
# topical
# topicality
# topo
# topographic
# topographical
# topography
# topological
# topology
# topotactic
# tor
# torque
# torques
# torsional
# total
# totality
# totally
# totem
# touched
# tough
# tourism
# tourist
# tow
# toward
# towards
# tower
# town
# toxic
# toxicity
# trace
# traceability
# traceable
# tracing
# track
# tracked
# tracker
# tract
# tractable
# traction
# trade
# trading
# tradition
# traditional
# traditionally
# traffic
# train
# trainable
# trained
# training
# trait
# trajectory
# transaction
# transcendent
# transcendental
# transcontinental
# transcript
# transcription
# transcriptionally
# transducer
# transfer
# transferred
# transferring
# transform
# transformation
# transformer
# transforming
# transgression
# transhuman
# transient
# transiently
# transistor
# transit
# transition
# transitional
# translate
# translation
# translational
# translator
# transmission
# transmit
# transmitter
# transparency
# transparent
# transpiration
# transplant
# transplantation
# transplanter
# transport
# transportation
# transported
# transporting
# transversal
# transverse
# trap
# trapezium
# trapezoid
# trapezoidal
# trapped
# trapping
# trauma
# traumatic
# traumatology
# travel
# traveled
# traveler
# traveling
# traversal
# traverse
# traversing
# tray
# treadmill
# treat
# treating
# treatment
# tree
# tremendous
# trend
# tri
# triad
# triage
# trial
# triangular
# tricarboxylic
# tricky
# tricuspid
# tricyclic
# tried
# trigger
# triggered
# trimethyl
# triple
# triplet
# triply
# triticum
# trivalent
# trivial
# trochophore
# trophic
# troposphere
# truckload
# true
# trueness
# truly
# truncated
# truncation
# truss
# trust
# trustfulness
# trusting
# trustworthiness
# trustworthy
# truth
# trying
# tsunami
# tube
# tuberculosis
# tulsi
# tumor
# tunable
# tune
# tuned
# tuning
# tunnel
# tunneling
# turbidness
# turbine
# turbines
# turbulence
# turbulent
# turkey
# turmoil
# turn
# turnaround
# turned
# turning
# turnover
# turns
# tutorial
# tweezers
# twelve
# twentieth
# twenty
# twice
# twin
# twinning
# twist
# twisted
# twisting
# two
# type
# typical
# typically
# typography
# typological
# u
# ubiquitous
# ulcer
# ulcerative
# ultimate
# ultimately
# ultra
# ultrasonic
# ultraviolet
# umbilical
# umbrella
# un
# unable
# unacceptably
# unaccounted
# unadjusted
# unaffected
# unaltered
# unannealed
# unannotated
# unauthorized
# unavailable
# unaware
# unbalance
# unbalanced
# unbiased
# unbleached
# unbounded
# unbranched
# uncertain
# uncertainty
# unchanged
# unclear
# uncommon
# unconditional
# uncorrelated
# uncover
# undefined
# under
# undergo
# undergoing
# undergrade
# undergraduate
# underground
# underlie
# underline
# underlying
# undermining
# underneath
# underpinning
# understand
# understandable
# understanding
# understood
# undertake
# undertook
# underwater
# underway
# underweight
# underwent
# undesirable
# undesired
# undetected
# undiagnosed
# undifferentiated
# undirected
# unearth
# unenriched
# uneven
# unevenly
# unevenness
# uneventful
# unexpected
# unexplored
# unexposed
# unfair
# unfamiliar
# unfamiliarity
# unfavorable
# unfeasible
# unidirectional
# unification
# unified
# uniform
# uniformity
# uniformly
# unify
# unilateral
# unintended
# union
# unipolar
# unique
# uniqueness
# unit
# united
# unity
# universal
# universality
# universally
# university
# unknown
# unlabeled
# unlawful
# unlawfully
# unless
# unlike
# unlikely
# unlimited
# unmanned
# unmatched
# unmet
# unmodeled
# unnatural
# unnecessary
# unofficial
# unoxidized
# unpacked
# unpaired
# unpleasant
# unpopular
# unprecedented
# unpredictable
# unprotected
# unpublished
# unrefined
# unrelated
# unreliable
# unresolved
# unsatisfactory
# unscented
# unsigned
# unsolved
# unspecific
# unstable
# unsteady
# unsuitable
# unsupervised
# unsuppressed
# untested
# until
# untrained
# untreated
# untrusted
# unused
# unusual
# unvisited
# unweighted
# up
# upcoming
# update
# uphold
# upon
# upper
# upstream
# uptake
# upward
# ural
# urate
# urban
# urbanization
# urea
# urgent
# urgently
# uric
# urinary
# urination
# urine
# us
# usability
# usage
# use
# used
# useful
# usefulness
# useless
# user
# usual
# usually
# uterine
# uterus
# utility
# utilization
# utilize
# utmost
# v
# vaccination
# vaccine
# vacuum
# vagina
# vaginal
# valence
# valency
# valent
# valgus
# valid
# validate
# validation
# validity
# valine
# valley
# valorization
# valuable
# valuation
# value
# valued
# valve
# van
# vanilla
# vapor
# variability
# variable
# variance
# variant
# variation
# variational
# varices
# varied
# varietal
# variety
# various
# vary
# vascular
# vasculitis
# vast
# vat
# vector
# vectorial
# vegetable
# vegetation
# vegetative
# vehicle
# vehicular
# vein
# velocity
# vendor
# venous
# ventricle
# ventricular
# venue
# verbal
# verification
# verifier
# verify
# versatile
# verse
# version
# versus
# vertebrate
# vertex
# vertical
# vertically
# vertices
# very
# vesicular
# vessel
# vet
# veterinary
# via
# viability
# viable
# vibrancy
# vibrating
# vibration
# vibrissal
# vice
# vicinity
# victor
# victory
# video
# view
# viewpoint
# village
# vim
# violation
# violence
# violent
# viral
# viremic
# virological
# virtual
# virtually
# virtue
# virulence
# virus
# vis
# viscosity
# viscous
# visibility
# visible
# vision
# visit
# visitor
# visual
# visualization
# visually
# vital
# vitality
# vitamin
# vocabulary
# vocal
# vocational
# voe
# voice
# vol
# volatile
# volatility
# voltage
# volume
# volumetric
# voluminous
# voluntary
# vote
# voting
# vowel
# voyage
# vulgare
# vulnerability
# vulnerable
# w
# waggle
# waiting
# wake
# walking
# wall
# walled
# walsh
# wan
# want
# war
# ward
# warehouse
# warming
# warning
# warranted
# was
# washout
# waste
# watch
# watching
# watchman
# water
# watered
# waterfall
# watering
# watermark
# watershed
# wave
# wavelet
# waviness
# wavy
# wax
# way
# wayang
# ways
# we
# weak
# weaken
# weakening
# weakly
# weakness
# wealth
# weapon
# wear
# wearable
# weather
# weathering
# weaver
# web
# webbing
# wedge
# week
# weigh
# weight
# weighted
# weighting
# welcome
# welfare
# well
# were
# west
# western
# wet
# wettability
# wetter
# wetting
# what
# wheat
# wheel
# when
# whenever
# where
# whereas
# whereby
# wherein
# whether
# whey
# which
# while
# whilst
# whisker
# white
# who
# whoever
# whole
# whom
# whose
# why
# wide
# widely
# widespread
# width
# wiener
# wild
# wildfire
# wilk
# will
# wilt
# wim
# win
# wind
# winding
# window
# wing
# winner
# winning
# winter
# wire
# wireless
# wise
# wish
# with
# withdraw
# withdrawing
# within
# without
# withstood
# witness
# wizard
# wolf
# woman
# won
# wood
# word
# wording
# work
# workability
# worked
# worker
# working
# workpiece
# workplace
# works
# world
# worn
# worse
# worsen
# worst
# worth
# worthless
# worthy
# wot
# would
# wound
# wounds
# wrap
# wrapping
# wrist
# writing
# written
# wrong
# x
# xi
# xylem
# y
# year
# yearly
# yeast
# yet
# yield
# yielding
# york
# you
# young
# younger
# your
# youth
# z
# zero
# zeta
# zinc
# zip
# zirconium
# zone
# zoom
# zoonotic
# zucchini
# zygote
#
# Length of Unique Sentences: 9932
# Length of Set of Words: 8004

# %%
from nltk.corpus import stopwords

# Assuming you have NLTK's stopwords dataset downloaded
# If not, you can download using:
# import nltk
# nltk.download('stopwords')

# Load English stopwords
stop_words = set(stopwords.words('english'))

def remove_stopwords_from_file(input_file, output_file):
    with open(input_file, 'r', encoding='utf-8') as f:
        lines = f.readlines()

    # Removing stopwords from each line
    cleaned_lines = []
    for line in lines:
        words = line.split()
        cleaned_line = ' '.join([word for word in words if word.lower() not in stop_words])
        cleaned_lines.append(cleaned_line)

    # Writing cleaned lines to a new file
    with open(output_file, 'w', encoding='utf-8') as f:
        for line in cleaned_lines:
            f.write(line + '\n')

# Usage
input_filename = 'shraddha7.txt'
output_filename = 'shraddha8.txt'
remove_stopwords_from_file(input_filename, output_filename)

# %%
from scipy.sparse import lil_matrix

def process_file(filename):
    with open(filename, 'r', encoding='utf-8') as f:
        lines = f.readlines()

    # Removing duplicates while maintaining order
    unique_sentences = sorted(set(lines), key=lines.index)
    
    # Extract all unique words, ensuring lowercase representation
    all_words = set()
    for sentence in unique_sentences:
        for word in sentence.split():
            all_words.add(word.lower())

    return unique_sentences, sorted(all_words)

unique_sentences, unique_words = process_file('shraddha8.txt')
word_to_index = {word: idx for idx, word in enumerate(unique_words)}

num_sentences = len(unique_sentences)
num_words = len(unique_words)

input_matrix = lil_matrix((num_sentences, num_words), dtype=int)
output_matrix = lil_matrix((num_sentences, num_words), dtype=int)

context_window = 3

for idx, sentence in enumerate(unique_sentences):
    # Input matrix
    for word in sentence.split():
        input_matrix[idx, word_to_index[word.lower()]] = 1

    # Output matrix
    context_start = max(0, idx - (context_window // 2))
    context_end = min(num_sentences, idx + (context_window // 2) + 1)
    
    for i in range(context_start, context_end):
        if i != idx:
            for word in unique_sentences[i].split():
                output_matrix[idx, word_to_index[word.lower()]] = 1

# Converting to CSR format for efficient row-wise operations
input_matrix = input_matrix.tocsr()
output_matrix = output_matrix.tocsr()

# %%
from collections import defaultdict
import math
from scipy.sparse import lil_matrix

# Step 1: Calculate IDF for each word in the vocabulary

word_sentence_indices = defaultdict(set)

for idx, sentence in enumerate(unique_sentences):
    for word in set(sentence.split()):  # Using set to avoid counting a word multiple times in the same sentence
        word_sentence_indices[word.lower()].add(idx)

idf = {}
for word, sentence_indices in word_sentence_indices.items():
    idf[word] = math.log(len(unique_sentences) / len(sentence_indices))

# Step 2: Calculate TF for each word in each sentence based on the context window and compute TF-IDF

tf_idf_matrix = lil_matrix((len(unique_sentences), len(unique_words)), dtype=float)

context_window_size = 3  # -1, 0, 1

for idx, sentence in enumerate(unique_sentences):
    word_counts = defaultdict(int)
    
    # Calculate TF (Term Frequency) with the context window
    context_start = max(0, idx - (context_window_size // 2))
    context_end = min(len(unique_sentences), idx + (context_window_size // 2) + 1)
    
    total_words_in_context = 0
    for i in range(context_start, context_end):
        total_words_in_context += len(unique_sentences[i].split())
        for word in unique_sentences[i].split():
            word_counts[word.lower()] += 1
    


    for word, count in word_counts.items():
        tf = count / total_words_in_context
        tf_idf_matrix[idx, unique_words.index(word)] = tf * idf[word]

# %%
vocab_size = input_matrix.shape[1]
print(vocab_size)
# Out:
# 7879

# %%
import tensorflow as tf

vocab_size = input_matrix.shape[1]
num_hiddens = 25

W1 = tf.Variable(tf.random.normal(shape=(vocab_size, num_hiddens), mean=0, stddev=0.01))
W2 = tf.Variable(tf.random.normal(shape=(num_hiddens, vocab_size), mean=0, stddev=0.01))

params = [W1, W2]

# %%
import tensorflow as tf
from scipy.sparse import lil_matrix
import random

# ...[Your previous function and data preparation definitions]

def net(X):
    X = tf.reshape(tf.cast(X, dtype=tf.float32), (-1, vocab_size))
    a1 = tf.matmul(X, W1)  # Replaced input_matrix with X
    a2 = tf.matmul(a1, W2)
    return softmax(a2)

def negative_log_likelihood(y_hat, y):
    # Compute the negative log likelihood for true class predictions
    return -tf.reduce_mean(tf.math.log(tf.boolean_mask(y_hat, y) + 1e-10))

def sgd(params, grads, lr):
    """Gradient descent."""
    for param, grad in zip(params, grads):
        param.assign_sub(lr * grad)

def softmax(X):
    X_exp = tf.exp(X)
    partition = tf.reduce_sum(X_exp, 1, keepdims=True)
    return X_exp / partition 

# ...[Your previous data loading and processing definitions]

# Converting sparse matrices to dense tensors for TensorFlow operations
input_tensor = tf.convert_to_tensor(tf_idf_matrix.toarray(), dtype=tf.float32)
output_tensor = tf.convert_to_tensor(output_matrix.toarray(), dtype=tf.float32)

# %%
print(input_matrix.shape)
print(tf_idf_matrix.shape)
print(output_matrix.shape)
# Out:
# (9906, 7879)
# (9906, 7879)
# (9906, 7879)
